# %%
# !pip install spotipy
# Out:
# ...
#                                               0.0/250.3 kB ? eta -:--:--
#                                               0.0/250.3 kB ? eta -:--:--
#                                               0.0/250.3 kB ? eta -:--:--
#                                               0.0/250.3 kB ? eta -:--:--
#                                               0.0/250.3 kB ? eta -:--:--
#                                               0.0/250.3 kB ? eta -:--:--
#                                               0.0/250.3 kB ? eta -:--:--
#                                               0.0/250.3 kB ? eta -:--:--
#      -                                        10.2/250.3 kB ? eta -:--:--
#      -                                        10.2/250.3 kB ? eta -:--:--
#      -                                        10.2/250.3 kB ? eta -:--:--
#      -                                        10.2/250.3 kB ? eta -:--:--
#      -                                        10.2/250.3 kB ? eta -:--:--
# ...

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

song_data = pd.read_csv('song_data.csv', encoding='latin1')

client_id = '0fa2352e1cff43a7b8008a75a096ce0f'
client_secret = 'cc8207b2d3a24af28494fcad1fdb670c'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def search_song(artist_name, song_name):
    query = f'artist:{artist_name} track:{song_name}'
    results = sp.search(q=query, limit=1, type='track')
    if results['tracks']['items']:
        track_info = results['tracks']['items'][0]
        return track_info
    else:
        return None

for index, row in song_data.iterrows():
    artist_name = row['artist_name']
    song_name = row['song_name']
    
    if '�' in song_name:
        print(f'Skipping song with strange sign: {song_name}')
        continue
    
    track_info = search_song(artist_name, song_name)
    if track_info:
        track_id = track_info['id']
        album_name = track_info['album']['name']
        release_date = track_info['album']['release_date']
        popularity = track_info['popularity']
        print(f'Song: {song_name} by {artist_name}')
        print(f'Track ID: {track_id}')
        print(f'Album: {album_name}')
        print(f'Release Date: {release_date}')
        print(f'Popularity: {popularity}')
        print('---')
    else:
        print(f'No information found for {song_name} by {artist_name}')
# Out:
# Song: Queen of Kings by Alessandra
# Track ID: 14LdhxElpZS0rKVV4nxtdA
# Album: Queen of Kings
# Release Date: 2023-01-09
# Popularity: 76
# ---
# Song: Dance (Our Own Party) by The Busker
# Track ID: 3natKRDYwMSPsLO9nX8y02
# Album: Dance (Our Own Party)
# Release Date: 2023-03-03
# Popularity: 46
# ---
# Song: Samo mi se spava by Luke Black
# Track ID: 7wLxoyWoClSUAlKGjaefQn
# Album: Samo mi se spava
# Release Date: 2023-02-02
# Popularity: 51
# ---
# Song: Aija by Sudden Lights
# Track ID: 2XhLiOVoMTWR0LNkvVEYA5
# Album: Aijā
# Release Date: 2023-01-27
# Popularity: 47
# ---
# Song: Ai coração by Mimicat
# Track ID: 2i2L1439P8JJRqp1jiKfUR
# Album: Festival da Canção 2023
# Release Date: 2023-01-27
# Popularity: 48
# ---
# Song: We Are One by Wild Youth
# Track ID: 2QYVjerrhcF6LuDC3zWbWx
# Album: We Are One
# Release Date: 2023-01-27
# Popularity: 46
# ---
# Song: Mama C! by Let 3
# Track ID: 7bdNn368lZOkRKVvqFO85J
# Album: Mama ŠČ! (Čemer Trap Remix)
# Release Date: 2023-07-07
# ...
